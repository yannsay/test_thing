# %% [markdown]
# # module 1
#
# > This is a module in a folder

# %%
#| default_exp components/module1

# %%
#| hide
from nbdev.showdoc import *

# %%
#| export
def papaya(): return "papaya"

# %%
papaya()
# Out:
# 'papaya'

# %%
#| hide
import nbdev; nbdev.nbdev_export()
