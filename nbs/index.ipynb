# %%
#| hide
from test_thing.core import *

# %% [markdown]
# # test_thing
#
# > My webappstest

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install test_thing in Development mode

# %% [markdown]
# ```sh
# # make sure test_thing package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to test_thing
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/yannsay/test_thing.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c yannsay test_thing
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install test_thing
# ```
#
#
# [repo]: https://github.com/yannsay/test_thing
# [docs]: https://yannsay.github.io/test_thing/
# [pypi]: https://pypi.org/project/test_thing/
# [conda]: https://anaconda.org/yannsay/test_thing

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/yannsay/test_thing
# [docs]: https://yannsay.github.io/test_thing/
# [pypi]: https://pypi.org/project/test_thing/
# [conda]: https://anaconda.org/yannsay/test_thing

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2

# %%
print("hello")
